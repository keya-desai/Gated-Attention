# %% [markdown]
# ## IMDB Review Classifier using BiLSTM
#
# GA-Net code without Auxilliary Network
# Backbone network = BiLSTM

# %%
# !pip3 install torchtext==0.4

# %%
import math
import numpy as np
import pandas as pd
import pdb

import torch
import torch.nn.functional as F
import torch.distributions
import torch.optim as optim
from torch import nn 
from torch.autograd import Variable

import torchtext
from torchtext import data
from torchtext import datasets
from torchtext.vocab import Vectors, GloVe

# from models.LSTM import LSTMClassifier

# %%
# model.py

class GANet(torch.nn.Module):
    def __init__(self, batch_size, num_classes, mlp_out_size, vocab_size, embedding_length, weights, aux_hidden_size = 100, backbone_hidden_size = 100, tau = 1, biDirectional_aux = False, biDirectional_backbone = False):
        super(GANet, self).__init__() 
        """
        Arguments
        ---------
        batch_size : Size of the batch which is same as the batch_size of the data returned by the TorchText BucketIterator
        output_size : 6 = (For TREC dataset)
        hidden_sie : Size of the hidden_state of the LSTM   (// Later BiLSTM)
        vocab_size : Size of the vocabulary containing unique words
        embedding_length : Embeddding dimension of GloVe word embeddings
        weights : Pre-trained GloVe word_embeddings which we will use to create our word_embedding look-up table 

        --------

        """

        self.batch_size = batch_size
        self.num_classes = num_classes
        self.vocab_size = vocab_size
        self.embedding_length = embedding_length
        self.aux_hidden_size = aux_hidden_size
        self.backbone_hidden_size = backbone_hidden_size 
        self.mlp_out_size = mlp_out_size
        self.biDirectional_aux = biDirectional_aux
        self.biDirectional_backbone = biDirectional_backbone
        self.tau = tau

        self.word_embeddings = nn.Embedding(vocab_size, embedding_length)
        self.word_embeddings.weights = nn.Parameter(weights, requires_grad=False)
        
        self.backbone = BackboneNet(self.batch_size, self.backbone_hidden_size, self.embedding_length, self.biDirectional_backbone)
        
        if(self.biDirectional_backbone):
            self.mlp = MLP(self.backbone_hidden_size*2, self.mlp_out_size)
            self.FF = nn.Linear(self.backbone_hidden_size*2, num_classes)
        else:
            self.mlp = MLP(self.backbone_hidden_size, self.mlp_out_size)
            self.FF = nn.Linear(self.backbone_hidden_size,self.num_classes)

    def forward(self, input_sequence, is_train = True):
        input_ = self.word_embeddings(input_sequence)
        out_lstm, final_hidden_state = self.backbone(input_)
        if self.biDirectional_backbone:
            final_hidden_state = final_hidden_state.view(2, 2, input_.shape[0], self.backbone_hidden_size) # num_layer x num_dir x batch x hidden
            final_hidden_state = final_hidden_state[-1]
            final_hidden_state = final_hidden_state.transpose(0,1).reshape(input_.shape[0], self.backbone_hidden_size*2)
        else:
            final_hidden_state = final_hidden_state[-1]
        
        ff_output = self.FF(final_hidden_state)
#         print("FF out size: ", ff_output.shape)
        predictions = torch.softmax(ff_output, dim = -1)
        return predictions

# %%
class BackboneNet(torch.nn.Module):
    """
        Arguments
        ---------
        batch_size : Size of the batch which is same as the batch_size of the data returned by the TorchText BucketIterator
        backbone_hidden_size : Size of the hidden_state of the LSTM   (* Later BiLSTM, check dims for BiLSTM *)
        embedding_length : Embeddding dimension of GloVe word embeddings
        --------
    """
    def __init__(self, batch_size, backbone_hidden_size, embedding_length, biDirectional = False, num_layers = 2):

        super(BackboneNet, self).__init__()
        self.batch_size = batch_size
        self.hidden_size = backbone_hidden_size
        self.embedding_length = embedding_length
        self.biDirectional	= biDirectional
        self.num_layers = num_layers

        self.backbone_lstm = nn.LSTM(self.embedding_length, self.hidden_size, bidirectional = self.biDirectional, batch_first = True, num_layers = self.num_layers)   # Dropout  

    def forward(self, input_sequence, batch_size=None):
        out_lstm, (final_hidden_state, final_cell_state) = self.backbone_lstm(input_sequence)   # ouput dim: ( batch_size x seq_len x hidden_size )
        return out_lstm, final_hidden_state

# %%
class MLP(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MLP, self).__init__()

        self.input_dim = input_dim
        self.output_dim = output_dim

        self.ff_1 = nn.Linear(self.input_dim, self.output_dim)
        self.relu = nn.ReLU()
        self.ff_2 = nn.Linear(self.output_dim,1)
        self.sigmoid = nn.Sigmoid()

    def forward(self,x):
        out_1 = self.ff_1(x)
        out_relu = self.relu(out_1)
        out_2 = self.ff_2(out_relu)
        out_sigmoid = self.sigmoid(out_2)

        return out_sigmoid

# %%
def clip_gradient(model, clip_value):
    params = list(filter(lambda p: p.grad is not None, model.parameters()))
    for p in params:
        p.grad.data.clamp_(-clip_value, clip_value)
    
def train_model(model, optim, train_iter, epoch, batch_size):
    total_epoch_loss = 0
    total_epoch_acc = 0
    # model.cuda()
#     optim = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()))
    steps = 0
    model.train()
    for idx, batch in enumerate(train_iter):
        text = batch.text[0]
        target = batch.label
        target = torch.autograd.Variable(target).long()
        if torch.cuda.is_available():
            text = text.cuda()
            target = target.cuda()
        if (text.size()[0] is not batch_size):# One of the batch returned by BucketIterator has length different than 32.
            continue
        optim.zero_grad()
        prediction = model(text, is_train = True)
#         print("prediction = ", prediction.shape)
#         print("target = ", target.shape)
#         print("prediction = ", prediction)
#         print("target = ", target)


        # Defualt - Cross entropy loss funtion
        loss = loss_fn(prediction, target)
        
        # print("loss = ", loss)
        
        num_corrects = (torch.max(prediction, 1)[1].view(target.size()).data == target.data).float().sum()
        acc = 100.0 * num_corrects/len(batch)
        loss.backward()
        clip_gradient(model, 1e-1)
        optim.step()
        steps += 1
        
        total_epoch_loss += loss.item()
        total_epoch_acc += acc.item()

        
    return total_epoch_loss/len(train_iter), total_epoch_acc/len(train_iter)

def eval_model(model, val_iter):
    total_epoch_loss = 0
    total_epoch_acc = 0
    total_attention =  0
    total_samples = 0 
    model.eval()
    with torch.no_grad():
        for idx, batch in enumerate(val_iter):
            text = batch.text[0]
            if (text.size()[0] is not 32):
                continue
            target = batch.label
            target = torch.autograd.Variable(target).long()
            if torch.cuda.is_available():
                text = text.cuda()
                target = target.cuda()
            prediction = model(text, is_train = False)
            # Sanity check
            # print("Test Prediction: ", prediction)

            # Defualt - Cross entropy loss funtion
            loss =  loss_fn(prediction, target)
            
            if math.isnan(loss.item()):
                print(prediction, target)
            
            num_corrects = (torch.max(prediction, 1)[1].view(target.size()).data == target.data).sum()
            acc = 100.0 * num_corrects/len(batch)
            total_epoch_loss += loss.item()
            total_epoch_acc += acc.item()
            
    return total_epoch_loss/len(val_iter), total_epoch_acc/len(val_iter)

# %%
# data.py
def load_IMDB_data(batch_size= 32, embedding_length = 100):
    # set up fields
    tokenize = lambda x: x.split()
    TEXT = data.Field(sequential=True, tokenize=tokenize, lower=True, include_lengths=True, batch_first=True, fix_length=100)
    # LABEL = data.LabelField()
    LABEL = data.LabelField(dtype=torch.float)

    # make splits for data
    train, test = datasets.IMDB.splits(TEXT, LABEL)
    train, valid = train.split() 
    
    # build the vocabulary
    TEXT.build_vocab(train, vectors=GloVe(name='6B', dim=embedding_length))
    LABEL.build_vocab(train)
    print(LABEL.vocab.__dict__)

    # make iterator for splits
    train_iter, valid_iter, test_iter = data.BucketIterator.splits(
      (train, valid, test), batch_size= batch_size, device=0)

    word_embeddings = TEXT.vocab.vectors
    vocab_size = len(TEXT.vocab)

    return TEXT, vocab_size, word_embeddings, train_iter, valid_iter, test_iter

# %%
# main.py
TEXT, vocab_size, word_embeddings, train_iter, valid_iter, test_iter = load_IMDB_data()
# Out:
# The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# {'freqs': Counter({'HUM': 869, 'ENTY': 859, 'DESC': 808, 'NUM': 632, 'LOC': 585, 'ABBR': 63}), 'itos': ['HUM', 'ENTY', 'DESC', 'NUM', 'LOC', 'ABBR'], 'unk_index': None, 'stoi': defaultdict(None, {'HUM': 0, 'ENTY': 1, 'DESC': 2, 'NUM': 3, 'LOC': 4, 'ABBR': 5}), 'vectors': None}

# %%
# Over-writing the loss function to simple cross entropy loss
loss_fn = F.cross_entropy

learning_rate = 2e-5
batch_size = 32
output_size = 2
hidden_size = 256
embedding_length = 100
num_classes = 2
mlp_out_size = 32
weights = word_embeddings
aux_hidden_size = 100
batch_hidden_size = 100
tau = 1

model = GANet(batch_size, num_classes, mlp_out_size, vocab_size, embedding_length, weights, biDirectional_backbone=True)
optim = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()))

# %%
num_bad_epochs = 0
epoch = 0
least_loss = float('inf')
training_stats = pd.DataFrame(columns=['Epoch', 'Train_Loss', 'Train_Acc', 'Val_Loss', 'Val_Acc'])

while(True):
    train_loss, train_acc = train_model(model, optim, train_iter, epoch, batch_size)
    val_loss, val_acc = eval_model(model, valid_iter) 
    print(f'Epoch: {epoch+1:02}')
    if val_loss < least_loss:
        least_loss = val_loss
        num_bad_epochs = 0
        print("*** Least validation loss")
        torch.save(model.state_dict(), "IMDB_BiLSTM_100")
    else:
        num_bad_epochs += 1
#     print(f'Epoch: {epoch+1:2}, Train Loss: {train_loss:.3f}, Train Acc: {train_acc:.2f}%')
    print(f'Train Loss: {train_loss:.3f}, Train Acc: {train_acc:.2f}%') 
    print(f'Val Loss: {val_loss:3f}, Val Acc: {val_acc:.2f}%')
    print("-------------")
    
    training_stats = training_stats.append(
        pd.Series([epoch+1, train_loss, train_acc, val_loss, val_acc], index=training_stats.columns), 
        ignore_index=True)
#     if num_bad_epochs >= 10:
#         break
        
    epoch += 1
    if epoch == 100:
        break
# Out:
# Epoch: 01
# *** Least validation loss
# Train Loss: 1.553, Train Acc: 47.40%
# Val Loss: 1.394544, Val Acc: 63.16%
# -------------
# Epoch: 02
# *** Least validation loss
# Train Loss: 1.341, Train Acc: 68.75%
# Val Loss: 1.324045, Val Acc: 67.73%
# -------------
# Epoch: 03
# *** Least validation loss
# Train Loss: 1.277, Train Acc: 75.05%
# Val Loss: 1.313090, Val Acc: 68.45%
# -------------
# Epoch: 04
# *** Least validation loss
# Train Loss: 1.243, Train Acc: 78.39%
# Val Loss: 1.283633, Val Acc: 72.12%
# -------------
# Epoch: 05
# Train Loss: 1.211, Train Acc: 81.46%
# Val Loss: 1.290041, Val Acc: 70.97%
# -------------
# Epoch: 06
# *** Least validation loss
# Train Loss: 1.180, Train Acc: 84.87%
# Val Loss: 1.259544, Val Acc: 74.46%
# -------------
# Epoch: 07
# Train Loss: 1.169, Train Acc: 85.94%
# Val Loss: 1.266113, Val Acc: 73.02%
# -------------
# Epoch: 08
# *** Least validation loss
# Train Loss: 1.154, Train Acc: 87.21%
# Val Loss: 1.255261, Val Acc: 74.58%
# -------------
# Epoch: 09
# *** Least validation loss
# Train Loss: 1.144, Train Acc: 88.33%
# Val Loss: 1.252062, Val Acc: 74.88%
# -------------
# Epoch: 10
# *** Least validation loss
# Train Loss: 1.138, Train Acc: 88.93%
# Val Loss: 1.245183, Val Acc: 75.42%
# -------------
# Epoch: 11
# *** Least validation loss
# Train Loss: 1.131, Train Acc: 89.56%
# Val Loss: 1.245182, Val Acc: 75.84%
# -------------
# Epoch: 12
# *** Least validation loss
# Train Loss: 1.121, Train Acc: 90.49%
# Val Loss: 1.235899, Val Acc: 76.92%
# -------------
# Epoch: 13
# *** Least validation loss
# Train Loss: 1.117, Train Acc: 90.99%
# Val Loss: 1.229313, Val Acc: 77.46%
# -------------
# Epoch: 14
# Train Loss: 1.115, Train Acc: 91.15%
# Val Loss: 1.236118, Val Acc: 76.62%
# -------------
# Epoch: 15
# Train Loss: 1.112, Train Acc: 91.51%
# Val Loss: 1.234511, Val Acc: 76.98%
# -------------
# Epoch: 16
# Train Loss: 1.108, Train Acc: 91.85%
# Val Loss: 1.234343, Val Acc: 76.56%
# -------------
# Epoch: 17
# Train Loss: 1.107, Train Acc: 91.93%
# Val Loss: 1.235004, Val Acc: 76.44%
# -------------
# Epoch: 18
# Train Loss: 1.108, Train Acc: 91.80%
# Val Loss: 1.235666, Val Acc: 76.74%
# -------------
# Epoch: 19
# *** Least validation loss
# Train Loss: 1.105, Train Acc: 92.16%
# Val Loss: 1.227591, Val Acc: 77.58%
# -------------
# Epoch: 20
# *** Least validation loss
# Train Loss: 1.101, Train Acc: 92.50%
# Val Loss: 1.227056, Val Acc: 77.64%
# -------------
# Epoch: 21
# Train Loss: 1.106, Train Acc: 91.95%
# Val Loss: 1.239884, Val Acc: 76.38%
# -------------
# Epoch: 22
# Train Loss: 1.097, Train Acc: 92.86%
# Val Loss: 1.232760, Val Acc: 77.16%
# -------------
# Epoch: 23
# Train Loss: 1.094, Train Acc: 93.20%
# Val Loss: 1.231322, Val Acc: 77.52%
# -------------
# Epoch: 24
# Train Loss: 1.095, Train Acc: 93.05%
# Val Loss: 1.236915, Val Acc: 76.26%
# -------------
# Epoch: 25
# Train Loss: 1.092, Train Acc: 93.49%
# Val Loss: 1.229233, Val Acc: 77.58%
# -------------
# Epoch: 26
# Train Loss: 1.089, Train Acc: 93.70%
# Val Loss: 1.229005, Val Acc: 77.34%
# -------------
# Epoch: 27
# Train Loss: 1.082, Train Acc: 94.51%
# Val Loss: 1.235301, Val Acc: 76.80%
# -------------
# Epoch: 28
# Train Loss: 1.085, Train Acc: 94.14%
# Val Loss: 1.239130, Val Acc: 75.90%
# -------------
# Epoch: 29
# Train Loss: 1.079, Train Acc: 94.82%
# Val Loss: 1.241470, Val Acc: 75.90%
# -------------
# Epoch: 30
# Train Loss: 1.075, Train Acc: 95.18%
# Val Loss: 1.241686, Val Acc: 76.20%
# -------------
# Epoch: 31
# Train Loss: 1.074, Train Acc: 95.23%
# Val Loss: 1.236034, Val Acc: 76.50%
# -------------
# Epoch: 32
# Train Loss: 1.074, Train Acc: 95.26%
# Val Loss: 1.244444, Val Acc: 75.66%
# -------------
# Epoch: 33
# Train Loss: 1.074, Train Acc: 95.26%
# Val Loss: 1.237093, Val Acc: 76.56%
# -------------
# Epoch: 34
# Train Loss: 1.073, Train Acc: 95.36%
# Val Loss: 1.242464, Val Acc: 75.60%
# -------------
# Epoch: 35
# Train Loss: 1.075, Train Acc: 95.18%
# Val Loss: 1.241841, Val Acc: 75.84%
# -------------
# Epoch: 36
# Train Loss: 1.075, Train Acc: 95.18%
# Val Loss: 1.243730, Val Acc: 75.96%
# -------------
# Epoch: 37
# Train Loss: 1.078, Train Acc: 94.82%
# Val Loss: 1.238526, Val Acc: 76.26%
# -------------
# Epoch: 38
# Train Loss: 1.078, Train Acc: 94.97%
# Val Loss: 1.239091, Val Acc: 76.56%
# -------------
# Epoch: 39
# Train Loss: 1.073, Train Acc: 95.34%
# Val Loss: 1.242933, Val Acc: 75.96%
# -------------
# Epoch: 40
# Train Loss: 1.070, Train Acc: 95.65%
# Val Loss: 1.232768, Val Acc: 76.92%
# -------------
# Epoch: 41
# Train Loss: 1.069, Train Acc: 95.78%
# Val Loss: 1.234148, Val Acc: 76.86%
# -------------
# Epoch: 42
# Train Loss: 1.069, Train Acc: 95.78%
# Val Loss: 1.234032, Val Acc: 76.92%
# -------------
# Epoch: 43
# Train Loss: 1.069, Train Acc: 95.78%
# Val Loss: 1.237358, Val Acc: 76.32%
# -------------
# Epoch: 44
# Train Loss: 1.069, Train Acc: 95.81%
# Val Loss: 1.239646, Val Acc: 76.14%
# -------------
# Epoch: 45
# Train Loss: 1.070, Train Acc: 95.68%
# Val Loss: 1.244907, Val Acc: 75.90%
# -------------
# Epoch: 46
# Train Loss: 1.072, Train Acc: 95.52%
# Val Loss: 1.252600, Val Acc: 75.06%
# -------------
# Epoch: 47
# Train Loss: 1.074, Train Acc: 95.29%
# Val Loss: 1.238312, Val Acc: 76.56%
# -------------
# Epoch: 48
# Train Loss: 1.075, Train Acc: 95.16%
# Val Loss: 1.237387, Val Acc: 76.32%
# -------------
# Epoch: 49
# Train Loss: 1.071, Train Acc: 95.60%
# Val Loss: 1.232677, Val Acc: 76.92%
# -------------
# Epoch: 50
# Train Loss: 1.068, Train Acc: 95.83%
# Val Loss: 1.232840, Val Acc: 76.68%
# -------------
# Epoch: 51
# *** Least validation loss
# Train Loss: 1.068, Train Acc: 95.86%
# Val Loss: 1.224808, Val Acc: 78.00%
# -------------
# Epoch: 52
# Train Loss: 1.070, Train Acc: 95.70%
# Val Loss: 1.234351, Val Acc: 76.80%
# -------------
# Epoch: 53
# *** Least validation loss
# Train Loss: 1.068, Train Acc: 95.89%
# Val Loss: 1.224101, Val Acc: 77.88%
# -------------
# Epoch: 54
# Train Loss: 1.067, Train Acc: 95.99%
# Val Loss: 1.225621, Val Acc: 77.58%
# -------------
# Epoch: 55
# Train Loss: 1.067, Train Acc: 95.94%
# Val Loss: 1.224145, Val Acc: 77.70%
# -------------
# Epoch: 56
# Train Loss: 1.069, Train Acc: 95.78%
# Val Loss: 1.238277, Val Acc: 76.44%
# -------------
# Epoch: 57
# Train Loss: 1.070, Train Acc: 95.62%
# Val Loss: 1.236959, Val Acc: 76.20%
# -------------
# Epoch: 58
# Train Loss: 1.068, Train Acc: 95.83%
# Val Loss: 1.228054, Val Acc: 77.82%
# -------------
# Epoch: 59
# Train Loss: 1.067, Train Acc: 95.96%
# Val Loss: 1.227392, Val Acc: 77.64%
# -------------
# Epoch: 60
# Train Loss: 1.066, Train Acc: 95.99%
# Val Loss: 1.232590, Val Acc: 77.40%
# -------------
# Epoch: 61
# Train Loss: 1.067, Train Acc: 95.99%
# Val Loss: 1.229592, Val Acc: 77.22%
# -------------
# Epoch: 62
# Train Loss: 1.065, Train Acc: 96.09%
# Val Loss: 1.237893, Val Acc: 76.32%
# -------------
# Epoch: 63
# Train Loss: 1.065, Train Acc: 96.12%
# Val Loss: 1.252003, Val Acc: 75.12%
# -------------
# Epoch: 64
# Train Loss: 1.067, Train Acc: 95.99%
# Val Loss: 1.250374, Val Acc: 75.36%
# -------------
# Epoch: 65
# Train Loss: 1.067, Train Acc: 95.89%
# Val Loss: 1.278896, Val Acc: 72.24%
# -------------
# Epoch: 66
# Train Loss: 1.066, Train Acc: 96.04%
# Val Loss: 1.236396, Val Acc: 76.80%
# -------------
# Epoch: 67
# Train Loss: 1.064, Train Acc: 96.25%
# Val Loss: 1.230263, Val Acc: 77.22%
# -------------
# Epoch: 68
# Train Loss: 1.069, Train Acc: 95.76%
# Val Loss: 1.254918, Val Acc: 74.94%
# -------------
# Epoch: 69
# Train Loss: 1.069, Train Acc: 95.76%
# Val Loss: 1.236511, Val Acc: 76.56%
# -------------
# Epoch: 70
# Train Loss: 1.070, Train Acc: 95.65%
# Val Loss: 1.232915, Val Acc: 76.86%
# -------------
# Epoch: 71
# Train Loss: 1.064, Train Acc: 96.25%
# Val Loss: 1.224405, Val Acc: 77.94%
# -------------
# Epoch: 72
# Train Loss: 1.063, Train Acc: 96.35%
# Val Loss: 1.227898, Val Acc: 77.58%
# -------------
# Epoch: 73
# Train Loss: 1.063, Train Acc: 96.41%
# Val Loss: 1.224372, Val Acc: 77.82%
# -------------
# Epoch: 74
# *** Least validation loss
# Train Loss: 1.062, Train Acc: 96.46%
# Val Loss: 1.221615, Val Acc: 78.00%
# -------------
# Epoch: 75
# *** Least validation loss
# Train Loss: 1.062, Train Acc: 96.48%
# Val Loss: 1.220151, Val Acc: 78.19%
# -------------
# Epoch: 76
# *** Least validation loss
# Train Loss: 1.061, Train Acc: 96.51%
# Val Loss: 1.219475, Val Acc: 78.19%
# -------------
# Epoch: 77
# Train Loss: 1.061, Train Acc: 96.51%
# Val Loss: 1.220580, Val Acc: 78.19%
# -------------
# Epoch: 78
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.220901, Val Acc: 78.19%
# -------------
# Epoch: 79
# Train Loss: 1.061, Train Acc: 96.51%
# Val Loss: 1.221535, Val Acc: 77.82%
# -------------
# Epoch: 80
# Train Loss: 1.061, Train Acc: 96.51%
# Val Loss: 1.221482, Val Acc: 77.94%
# -------------
# Epoch: 81
# Train Loss: 1.061, Train Acc: 96.54%
# Val Loss: 1.221521, Val Acc: 78.12%
# -------------
# Epoch: 82
# Train Loss: 1.061, Train Acc: 96.54%
# Val Loss: 1.220399, Val Acc: 78.19%
# -------------
# Epoch: 83
# *** Least validation loss
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.218886, Val Acc: 78.19%
# -------------
# Epoch: 84
# *** Least validation loss
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.216364, Val Acc: 78.55%
# -------------
# Epoch: 85
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.217286, Val Acc: 78.61%
# -------------
# Epoch: 86
# Train Loss: 1.061, Train Acc: 96.59%
# Val Loss: 1.219430, Val Acc: 78.31%
# -------------
# Epoch: 87
# Train Loss: 1.061, Train Acc: 96.54%
# Val Loss: 1.219825, Val Acc: 78.19%
# -------------
# Epoch: 88
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.224596, Val Acc: 77.58%
# -------------
# Epoch: 89
# Train Loss: 1.062, Train Acc: 96.43%
# Val Loss: 1.225394, Val Acc: 77.52%
# -------------
# Epoch: 90
# Train Loss: 1.064, Train Acc: 96.20%
# Val Loss: 1.223083, Val Acc: 78.00%
# -------------
# Epoch: 91
# Train Loss: 1.071, Train Acc: 95.52%
# Val Loss: 1.229842, Val Acc: 77.40%
# -------------
# Epoch: 92
# Train Loss: 1.066, Train Acc: 95.99%
# Val Loss: 1.226848, Val Acc: 77.58%
# -------------
# Epoch: 93
# Train Loss: 1.062, Train Acc: 96.43%
# Val Loss: 1.236465, Val Acc: 76.80%
# -------------
# Epoch: 94
# Train Loss: 1.061, Train Acc: 96.51%
# Val Loss: 1.225058, Val Acc: 77.76%
# -------------
# Epoch: 95
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.227506, Val Acc: 77.70%
# -------------
# Epoch: 96
# Train Loss: 1.061, Train Acc: 96.56%
# Val Loss: 1.225741, Val Acc: 77.70%
# -------------
# Epoch: 97
# Train Loss: 1.061, Train Acc: 96.61%
# Val Loss: 1.224731, Val Acc: 78.00%
# -------------
# Epoch: 98
# Train Loss: 1.060, Train Acc: 96.67%
# Val Loss: 1.226991, Val Acc: 77.58%
# -------------
# Epoch: 99
# Train Loss: 1.060, Train Acc: 96.67%
# Val Loss: 1.227567, Val Acc: 77.52%
# -------------
# Epoch: 100
# Train Loss: 1.060, Train Acc: 96.67%
# Val Loss: 1.230686, Val Acc: 76.98%
# -------------

# %%
training_stats.to_csv("IMDB_BiLSTM_100.csv")

# %%
# # Print model's state_dict
# print("Model's state_dict:")
# for param_tensor in model.state_dict():
#     print(param_tensor, "\t", model.state_dict()[param_tensor].size())

# # Print optimizer's state_dict
# print("Optimizer's state_dict:")
# for var_name in optim.state_dict():
#     print(var_name, "\t", optim.state_dict()[var_name])

# %%
loaded_model = GANet(batch_size, num_classes, mlp_out_size, vocab_size, embedding_length, weights,biDirectional_backbone=True)
loaded_model.load_state_dict(torch.load('IMDB_BiLSTM_100'))
loaded_model.eval()
# Out:
# GANet(
#   (word_embeddings): Embedding(6953, 100)
#   (backbone): BackboneNet(
#     (backbone_lstm): LSTM(100, 100, num_layers=2, batch_first=True, bidirectional=True)
#   )
#   (mlp): MLP(
#     (ff_1): Linear(in_features=200, out_features=32, bias=True)
#     (relu): ReLU()
#     (ff_2): Linear(in_features=32, out_features=1, bias=True)
#     (sigmoid): Sigmoid()
#   )
#   (FF): Linear(in_features=200, out_features=6, bias=True)
# )

# %%
test_loss, test_acc = eval_model(loaded_model, test_iter)
print(f'Test Loss: {test_loss:.3f}, Test Acc: {test_acc:.2f}')
# Out:
# Test Loss: 1.103, Test Acc: 81.25

# %%
def test_sentence(test_sen):
    test_sen_list = TEXT.preprocess(test_sen)
    print(test_sen_list)
    test_sen = [[TEXT.vocab.stoi[x] for x in test_sen_list]]
    # print(test_sen)

    test_sen = np.asarray(test_sen)
    test_sen = torch.LongTensor(test_sen)
    test_tensor = Variable(test_sen, volatile=True)

    # print(test_tensor)
    loaded_model.eval()
#     print(test_tensor.shape)
    prediction = loaded_model(test_tensor, is_train = False)
    print("prediction =", prediction)

    out_class = torch.argmax(prediction)
    return out_class

''' Let us now predict the sentiment on a single sentence just for the testing purpose. '''
test_sen1 = "This is one of the best creation of Nolan. I can say, it's his magnum opus. Loved the soundtrack and especially those creative dialogues."
test_sen2 = "Ohh, such a ridiculous movie. Not gonna recommend it to anyone. Complete waste of time and money."

print('------------')
x = test_sentence(test_sen1)
print(x)
print('------------')
x = test_sentence(test_sen2)
print(x)
print('------------')
# Out:
# ['what', 'does', 'the', 'six-footed', 'musca', 'domestica', 'become', 'when', 'it', 'enters', 'a', 'house', '?']
# prediction = tensor([[3.6286e-03, 6.6554e-02, 1.1830e-05, 4.3272e-01, 2.9261e-03, 4.9416e-01]],
#        grad_fn=<SoftmaxBackward>)
# tensor(5)
# ------------
# ['who', 'killed', 'gandhi', '?']
# prediction = tensor([[1.0000e+00, 6.1874e-08, 1.3324e-10, 2.8210e-09, 1.9908e-09, 4.9990e-11]],
#        grad_fn=<SoftmaxBackward>)
# tensor(0)
# ------------
# ['what', 'does', 'target', 'heart', 'rate', 'mean', '?']
# prediction = tensor([[7.1802e-09, 2.6184e-07, 9.8710e-01, 3.0082e-06, 4.3802e-03, 8.5207e-03]],
#        grad_fn=<SoftmaxBackward>)
# tensor(2)
# ------------
# ['how', 'old', 'was', 'joan', 'of', 'arc', 'when', 'she', 'died', '?']
# prediction = tensor([[2.7059e-07, 6.4462e-11, 3.8280e-09, 1.0000e+00, 7.7517e-08, 1.0074e-07]],
#        grad_fn=<SoftmaxBackward>)
# tensor(3)
# ------------
# ['where', 'on', 'the', 'body', 'is', 'a', 'mortarboard', 'worn', '?']
# prediction = tensor([[2.2445e-07, 7.8214e-08, 6.2862e-08, 3.4735e-06, 1.0000e+00, 1.6961e-07]],
#        grad_fn=<SoftmaxBackward>)
# tensor(4)
# ------------
# ['what', 'does', 'i.v.', 'stand', 'for', '?']
# prediction = tensor([[1.4492e-10, 2.0366e-07, 1.6385e-08, 1.7790e-07, 2.1569e-05, 9.9998e-01]],
#        grad_fn=<SoftmaxBackward>)
# tensor(5)
# ------------
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   if __name__ == '__main__':

# %%
import matplotlib.pyplot as plt
plt.plot(training_stats['Train_Loss'], label="Train")
plt.plot(training_stats['Val_Loss'], label="Validation")
plt.legend()
plt.show()

# %%
plt.plot(training_stats['Train_Acc'], label="Train")
plt.plot(training_stats['Val_Acc'], label="Validation")
plt.legend()
plt.show()
